# %%
# 数据来源于github，第一列为病人id号，第二列为癌症诊断类型（良性和恶性两种），其余列为与发病率相关的特征
import pandas as pd
import numpy as np
from sklearn.neighbors import KNeighborsClassifier as KNN
from pandas import Series,DataFrame
import random
data = pd.read_csv(r'E:\github\Machine__Learning\data\2.KNN\cancer_data\data.csv')

# %%
data.head()
# Out:
#          id diagnosis  ...  symmetry_worst  fractal_dimension_worst
# 0    842302         M  ...          0.4601                  0.11890
# 1    842517         M  ...          0.2750                  0.08902
# 2  84300903         M  ...          0.3613                  0.08758
# 3  84348301         M  ...          0.6638                  0.17300
# 4  84358402         M  ...          0.2364                  0.07678
#
# [5 rows x 32 columns]

# %%
# 获取目标值（即诊断结果）
label = data['diagnosis']
# 训练数据，特征，即第三列之后的特征
char_value = data.iloc[:,2:]

# %%
label.head()
# Out:
# 0    M
# 1    M
# 2    M
# 3    M
# 4    M
# Name: diagnosis, dtype: object

# %%
char_value.head()
# Out:
#    radius_mean  texture_mean  ...  symmetry_worst  fractal_dimension_worst
# 0        17.99         10.38  ...          0.4601                  0.11890
# 1        20.57         17.77  ...          0.2750                  0.08902
# 2        19.69         21.25  ...          0.3613                  0.08758
# 3        11.42         20.38  ...          0.6638                  0.17300
# 4        20.29         14.34  ...          0.2364                  0.07678
#
# [5 rows x 30 columns]

# %%
char_value.shape
# Out:
# (569, 30)

# %%
# 划分数据，其中10%作为测试集、90%作为训练集
# 第一种方法：
num = data.shape[0]
print(num*90//100)
train_data = data[:512]
test_data = data[512:]
# 第二种方法
from sklearn.model_selection import train_test_split
label_train,label_test,char_value_train,char_value_test = train_test_split(label,char_value,test_size=0.2)
# 本次使用第二种方法
# Out:
# 512

# %%
train_data.head()
# Out:
#          id diagnosis  ...  symmetry_worst  fractal_dimension_worst
# 0    842302         M  ...          0.4601                  0.11890
# 1    842517         M  ...          0.2750                  0.08902
# 2  84300903         M  ...          0.3613                  0.08758
# 3  84348301         M  ...          0.6638                  0.17300
# 4  84358402         M  ...          0.2364                  0.07678
#
# [5 rows x 32 columns]

# %%
test_data.head()
# Out:
#            id diagnosis  ...  symmetry_worst  fractal_dimension_worst
# 512    915691         M  ...          0.3585                  0.11090
# 513    915940         B  ...          0.2626                  0.07048
# 514  91594602         M  ...          0.2282                  0.06954
# 515    916221         B  ...          0.3060                  0.06783
# 516    916799         M  ...          0.3074                  0.07863
#
# [5 rows x 32 columns]

# %%
# 构建knn算法
knn = KNN(n_neighbors=5, algorithm='ball_tree')
# 算法训练数据
knn.fit(char_value_train,label_train)
# 使用算法进行预测()
predict_result = knn.predict(char_value_test)

# %%
# 预测数据
predict_result
# Out:
# array(['B', 'M', 'B', 'M', 'B', 'B', 'B', 'M', 'M', 'B', 'B', 'M', 'M',
#        'B', 'B', 'B', 'B', 'M', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B',
#        'B', 'M', 'M', 'M', 'M', 'B', 'B', 'M', 'M', 'M', 'B', 'B', 'M',
#        'B', 'B', 'M', 'M', 'B', 'M', 'M', 'B', 'M', 'B', 'M', 'M', 'B',
#        'B', 'M', 'M', 'M', 'B', 'B', 'M', 'B', 'B', 'B', 'B', 'B', 'B',
#        'B', 'B', 'B', 'B', 'M', 'M', 'B', 'B', 'B', 'B', 'B', 'B', 'B',
#        'M', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'M', 'M', 'B', 'B', 'M',
#        'M', 'B', 'M', 'B', 'B', 'M', 'B', 'M', 'B', 'B', 'B', 'B', 'B',
#        'B', 'B', 'B', 'B', 'B', 'M', 'M', 'B', 'B', 'M'], dtype=object)

# %%
predict_result_prob = knn.predict_proba(char_value_test)

# %%
# 真实数据
label_test.values
# Out:
# array(['B', 'M', 'B', 'M', 'B', 'B', 'B', 'M', 'B', 'B', 'B', 'M', 'M',
#        'B', 'M', 'B', 'B', 'M', 'B', 'B', 'B', 'B', 'B', 'M', 'B', 'B',
#        'M', 'M', 'M', 'M', 'M', 'B', 'B', 'M', 'M', 'M', 'B', 'B', 'M',
#        'B', 'B', 'M', 'M', 'B', 'M', 'M', 'M', 'M', 'B', 'M', 'M', 'B',
#        'B', 'M', 'M', 'M', 'B', 'B', 'M', 'B', 'B', 'B', 'B', 'M', 'B',
#        'B', 'B', 'B', 'B', 'M', 'M', 'B', 'B', 'B', 'B', 'B', 'B', 'B',
#        'M', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'M', 'M', 'B', 'B', 'M',
#        'M', 'B', 'M', 'B', 'B', 'M', 'B', 'M', 'B', 'B', 'B', 'B', 'B',
#        'B', 'B', 'B', 'B', 'M', 'M', 'M', 'M', 'B', 'M'], dtype=object)

# %%
# 预测结果与实际结果
predict_result == label_test.values
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True, False,
#         True,  True,  True,  True,  True, False,  True,  True,  True,
#         True,  True,  True,  True,  True, False,  True,  True, False,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True, False,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#        False,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#        False,  True,  True, False,  True,  True])
